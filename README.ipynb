# %% [markdown]
# # AI-ML-DS Roadmap
#
# 1. **Mathematics**
# 2. **Data Analysis**
#    1. Numpy
#    2. Pandas
#    3. Matplotlib
#    4. Seabon
#    5. EDA(Exploratery Data Analysis)
# 3. **Machine Learning**
#     1. Supervise Learning
#         1. Linear Regration (Regration)
#         2. Logistic Regration (Classification)
#         3. Descision Tree (Classification)
#         4. Random Forest (Classification)
#     2. Unsupervise Learning
#         1. K-Means
#         2. PCA(Principle Component Analysis)
#         3. LDA
#         4. Time Serise
#     3. Reinforcement Learning
# 4. **NLP**
# 5. **DL**
#     1. Nural Network
#         1. ANN
#         2. CNN
#         3. RNN
# 6. **GenAI**
# 7. **MLOPS**
# 8. **Computer Vision**
#     1. **OpenCV**
#
# ---
#
# #### Semester 1 Reference
#
# * Data Analysis and ML
#     * **Online Sessions -PCP-CS Weekday BC=251205_(Python)**
# * Deep Learning
#     * **Online Session-PCP-Artificial Intelligence-Weekday – BC=250109**
# * GenAI
#     * **Online Session-PCP (DS-AI) BC=251401_(Gen AI)**
# * Artificial Intelligence :
#     * **Online Session-PCP-DS-Weekday-BC=251711_(Artificial Intelligence)**
# * MLOPS :
#     * **Online Session-PCP-Weekday-BC=251401_(MlOps)**
#
# ---
#
# #### Semester 2 Reference
#
# ---
#
# Paused on
# Decision Tree Thoery – 23/07/2025 – Prof Vivek -> 35::41
