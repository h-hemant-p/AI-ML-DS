# %% [markdown]
# # Random Forest
#
# * Random forest is based on decision tree.
# * Means It can be used in creating both classification model and regration model just like decision tree.
# * Random Forest is an ensemble machine learning algorithm.
# * It combines multiple Decision Trees to improve performance.
# * Works for:
#     - Classification
#     - Regression
# * Idea: Instead of relying on one tree → use many trees → take combined decision.
# * The number of Base models in a Random Forest is a Hyper Parameter.
# * Base learner, Base model, base Estimator - referes to the individual model in ensemble algorithm
# * Consolidating balearner prediction
#     - Majority Voting (If problem is an classification problem)
#     - Averaging (If problem is an regration problem)
# * Every input should be feeding to all all base models
# --
# * **Hyper Parameters in Random Forest**
#     1. n_estimators : Number of decision trees
#     2. max_features : Maximum limit for features for D-Trees
#     3. min_sample_leaf : (Pruning)minimum number of leafs that should be required to split an internal node
#     4. random_state : set it to an integer to generate same randomness every time
#     5. oob_score : random forest cross validation method. In this sampling, about 63% of the data is not used to train the model and can be used to evaluate its performance.
#     6. n_jobs : hyperparameter tell the engine how many processors it is allowed to use.
# --
# * Random Forest uses bagging to construct ensembles of randomized decision trees
# * **Bagging** :  Bootstrap Sampling and aggregation (together called Bagging).
#
# * Uses Bootstrap Sampling to derive multiple new datasets from one initial training dataset to train multiple base models.
# * Because if we will trail all base models with same dataset then all models performance will be same that we dont want.
#
# * **Bootstrap Sampling**
#     * Bootstrap Sampling is a method where we:
#         - Randomly select data points from a dataset
#         - With replacement
#         - 👉 With replacement means:
#             - The same data point can be selected multiple times
#             - Some data points may not be selected at all
#     * Size of sample = size of original dataset
#     * Around ~63% unique data is used per sample and Rest are duplicates
#     * Some points repeated, Some points left out
#     * 👉 The left-out data is called:🔸 Out-of-Bag (OOB) Data (Used for model validation{Validation Set})
#
# * Considers random subset of features when splitting a node
# * The greater diversity among combined models, the more accurate the resulting ensemble model
# * max_feature -> hyperparameter
# * The role of max_feature hyperparameter is to set the limit of features(columns) to each D-Tree and Features will be selected in randomized order
# * Because of these reasons Random Forest becomes the less prone to over fitting.
#
# ![image.png](attachment:image.png)
#
#
# * In Random Forest we have 2 levels of ramdomness
#     1. Row wise Randomness (in Bootstrap Sampling)
#     2. Column(Feature) wise Randomness
# ---

# %% [markdown]
# * **Ensemble Learning**
# Ensemble learning is a machine learning technique that aggregates two or more learners to produce better predections.

# %% [markdown]
# noise
# scatterplot
#
# hyperparameter tunning
# dataset = test . validation , test
# Hyper parameter
# gradient descent
# Shallow = less complex
# Regularization : Any technique that helps you avoid overfitting
# Begging = Bootstrap sampling + Aggregation
