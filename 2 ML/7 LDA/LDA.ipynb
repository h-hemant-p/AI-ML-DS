# %% [markdown]
# # Linear Discriminant Analysis (LDA)
#
# * Linear Discriminant Analysis (LDA) is a supervised machine learning algorithm used for:
#     1. Classification
#     2. Dimensionality Reduction
# * **Key Idea:** Select the best direction for projection that
#     1. Maximizes their between-class separability while ̈
#     2. Minimizing their within-class variability

# %%
https://drive.google.com/drive/folders/1C_swbZ0zqWa32dYmFTeUL2IcU2RcixfU
