# %% [markdown]
# # Simple Linear Regration

# %%
#load the dataset
import pandas as pd
data=pd.read_csv("Salary_Data.csv")
data = data.drop('Age',axis=1)
data = data.drop('Gender',axis=1)
data = data.drop('Job Title',axis=1)
data = data.drop('Education Level',axis=1)
print(data)
# Out:
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...                   ...       ...
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0
#
# [6704 rows x 2 columns]

# %%
#data cleaning
data.isna().sum()
# Out:
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
#data preprocessing #no need
data.fillna(data.mean(),inplace=True)
data.isna().sum()
# Out:
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
#split into x and y
x=data.iloc[:,[0]]
y=data.iloc[:,1]
#split into train and test
from sklearn.model_selection import train_test_split
xtr,xte,ytr,yte=train_test_split(x,y,test_size=0.2,random_state=42)
#train using lr
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xtr,ytr)
yp=model.predict(xte)
#accuracy
from sklearn.metrics import r2_score
print(r2_score(yte,yp))

#y=mx+c
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(xte,yp)
plt.show()
# Out:
# 0.6708355200992153

# %%
model.coef_
# Out:
# array([6975.85402481])

# %%
model.intercept_
# Out:
# np.float64(58366.54243606136)

# %%
model.predict([[10]])
# Out:
# c:\Users\Hemant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([128965.01501086])
