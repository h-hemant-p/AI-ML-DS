# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/US_honey_dataset.csv')

# %%
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %% [markdown]
# EDA-Exploratory Data Analysis-The step we perform for data cleaning and analysis using pandas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  colonies_number  yield_per_colony    production  \
# count  1115.00000      1115.000000       1115.000000  1.115000e+03
# mean    557.00000     62438.565022         59.743498  2.851268e+06
# std     322.01708     92648.175955         19.940500  5.561202e+06
# min       0.00000      2000.000000         19.000000  1.200000e+04
# 25%     278.50000      9000.000000         45.000000  2.460000e+05
# 50%     557.00000     26000.000000         57.000000  8.280000e+05
# 75%     835.50000     69000.000000         71.000000  2.700000e+06
# max    1114.00000    550000.000000        155.000000  3.906000e+07
#
#              stocks  average_price  value_of_production         year
# count  1.115000e+03    1115.000000         1.115000e+03  1115.000000
# mean   1.172625e+06     140.623076         5.667412e+06  2007.740807
# std    2.049556e+06     107.011544         9.459460e+06     7.823002
# min    9.000000e+03       1.300000         1.060000e+05  1995.000000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'state', 'colonies_number', 'yield_per_colony',
#        'production', 'stocks', 'average_price', 'value_of_production', 'year'],
#       dtype='object')

# %% [markdown]
# Q1.Which state is having the highest honey production througout all these years?  represent it using a bar graph.

# %%
high_prod_state=df.groupby('state')['production'].sum().sort_values(ascending=False).reset_index()

# %%
high_prod_state
# Out:
#             state  production
# 0     NorthDakota   513742000
# 1      California   423876000
# 2     SouthDakota   355726000
# 3         Florida   280934000
# 4         Montana   197173000
# 5       Minnesota   176581000
# 6           Texas   129441000
# 7        Michigan   101063000
# 8       Wisconsin    99909000
# 9           Idaho    87188000
# 10        NewYork    78444000
# 11       Nebraska    63655000
# 12      Louisiana    60568000
# 13        Georgia    57426000
# 14     Washington    53238000
# 15       Arkansas    51846000
# 16           Iowa    48607000
# 17        Wyoming    43921000
# 18         Oregon    43789000
# 19        Arizona    38844000
# 20       Colorado    32660000
# 21           Ohio    22485000
# 22   Pennsylvania    21370000
# 23    Mississippi    21235000
# 24           Utah    20369000
# 25       Missouri    17904000
# 26         Hawaii    15420000
# 27        Alabama    14467000
# 28         Kansas    14138000
# 29      NewMexico    10082000
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=high_prod_state,x='production',y='state',palette='hsv')
plt.show()
# Out:
# /tmp/ipython-input-27-1519391709.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=high_prod_state,x='production',y='state',palette='hsv')

# %%
high_prod_state=df.groupby('state')['production'].sum().sort_values(ascending=False).reset_index()

# %%
high_prod_state
# Out:
#             state  production
# 0     NorthDakota   513742000
# 1      California   423876000
# 2     SouthDakota   355726000
# 3         Florida   280934000
# 4         Montana   197173000
# 5       Minnesota   176581000
# 6           Texas   129441000
# 7        Michigan   101063000
# 8       Wisconsin    99909000
# 9           Idaho    87188000
# 10        NewYork    78444000
# 11       Nebraska    63655000
# 12      Louisiana    60568000
# 13        Georgia    57426000
# 14     Washington    53238000
# 15       Arkansas    51846000
# 16           Iowa    48607000
# 17        Wyoming    43921000
# 18         Oregon    43789000
# 19        Arizona    38844000
# 20       Colorado    32660000
# 21           Ohio    22485000
# 22   Pennsylvania    21370000
# 23    Mississippi    21235000
# 24           Utah    20369000
# 25       Missouri    17904000
# 26         Hawaii    15420000
# 27        Alabama    14467000
# 28         Kansas    14138000
# 29      NewMexico    10082000
# ...

# %%
high_prod_state=df.groupby('state')['production'].sum().sort_values(ascending=False).reset_index()

# %%
high_prod_state
# Out:
#             state  production
# 0     NorthDakota   513742000
# 1      California   423876000
# 2     SouthDakota   355726000
# 3         Florida   280934000
# 4         Montana   197173000
# 5       Minnesota   176581000
# 6           Texas   129441000
# 7        Michigan   101063000
# 8       Wisconsin    99909000
# 9           Idaho    87188000
# 10        NewYork    78444000
# 11       Nebraska    63655000
# 12      Louisiana    60568000
# 13        Georgia    57426000
# 14     Washington    53238000
# 15       Arkansas    51846000
# 16           Iowa    48607000
# 17        Wyoming    43921000
# 18         Oregon    43789000
# 19        Arizona    38844000
# 20       Colorado    32660000
# 21           Ohio    22485000
# 22   Pennsylvania    21370000
# 23    Mississippi    21235000
# 24           Utah    20369000
# 25       Missouri    17904000
# 26         Hawaii    15420000
# 27        Alabama    14467000
# 28         Kansas    14138000
# 29      NewMexico    10082000
# ...

# %% [markdown]
# Q2.Which state is having the highest and the lowest yield per colony?represent it using bar graph.

# %%
high_yield_col=df.groupby('state')['yield_per_colony'].mean().sort_values(ascending=False).reset_index()

# %%
high_yield_col
# Out:
#             state  yield_per_colony
# 0          Hawaii        103.777778
# 1       Louisiana         92.814815
# 2     Mississippi         86.703704
# 3     NorthDakota         83.925926
# 4         Montana         79.555556
# 5         Florida         72.444444
# 6     SouthDakota         72.222222
# 7           Texas         71.148148
# 8       Wisconsin         70.222222
# 9        Arkansas         69.851852
# 10      Minnesota         69.814815
# 11           Ohio         65.296296
# 12       Michigan         64.925926
# 13        NewYork         64.629630
# 14       Nebraska         64.037037
# 15        Wyoming         62.888889
# 16        Vermont         62.000000
# 17           Iowa         61.444444
# 18  SouthCarolina         60.583333
# 19        Alabama         59.814815
# 20        Indiana         59.444444
# 21         Kansas         58.148148
# 22       Illinois         57.851852
# 23       Colorado         56.296296
# 24      NewMexico         56.111111
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=high_yield_col,x='yield_per_colony',y='state',palette='hsv')
plt.show()
# Out:
# /tmp/ipython-input-36-3401677926.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=high_yield_col,x='yield_per_colony',y='state',palette='hsv')

# %% [markdown]
# Q3.Which year witnesses the highest profit in honey production?use bar graph to plot it.

# %%
high_prof_year=df.groupby('year')['value_of_production'].sum().sort_values(ascending=False).reset_index()

# %%
high_prof_year
# Out:
#     year  value_of_production
# 0   2014            384483000
# 1   2016            335285000
# 2   2018            330766000
# 3   2017            326198000
# 4   2015            322505000
# 5   2013            315118000
# 6   2021            314413000
# 7   2019            303438000
# 8   2020            301831000
# 9   2012            280725000
# 10  2010            278370000
# 11  2011            258688000
# 12  2003            254833000
# 13  2008            224113000
# 14  2002            220747000
# 15  2009            207602000
# 16  2004            199044000
# 17  1996            179774000
# 18  2006            159363000
# 19  2007            155867000
# 20  2005            155611000
# 21  1998            145998000
# 22  1997            145598000
# 23  1995            137324000
# 24  2000            131022000
# 25  2001            126261000
# 26  1999            124187000

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=high_prof_year,x='year',y='value_of_production',palette='hsv')
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipython-input-40-187251868.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=high_prof_year,x='year',y='value_of_production',palette='hsv')

# %% [markdown]
# Q4.Which state was having the highest stock in 2020?represent it using the bar graph.

# %%
df_2020=df[df['year']==2020]

# %%
high_stock_state=df_2020.groupby('state')['stocks'].sum().sort_values(ascending=False).reset_index()

# %%
high_stock_state
# Out:
#             state   stocks
# 0     SouthDakota  8668000
# 1     NorthDakota  8108000
# 2         Montana  3208000
# 3      California  2752000
# 4       Minnesota  2495000
# 5        Michigan  1384000
# 6            Iowa  1259000
# 7           Texas  1253000
# 8          Oregon  1102000
# 9         Florida   883000
# 10      Wisconsin   855000
# 11        NewYork   844000
# 12     Washington   798000
# 13          Idaho   637000
# 14        Wyoming   608000
# 15           Ohio   576000
# 16       Colorado   455000
# 17        Georgia   412000
# 18   Pennsylvania   392000
# 19        Arizona   360000
# 20       Nebraska   250000
# 21      Louisiana   228000
# 22       Arkansas   176000
# 23           Utah   171000
# 24         Kansas   164000
# 25       Illinois   156000
# 26        Indiana   149000
# 27    Mississippi   146000
# 28  NorthCarolina   123000
# 29       Missouri   100000
# 30        Vermont    96000
# 31      NewJersey    91000
# 32         Hawaii    79000
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=high_stock_state,x='state',y='stocks',palette='hsv')
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipython-input-46-2736609019.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=high_stock_state,x='state',y='stocks',palette='hsv')

# %% [markdown]
# Q-Which state is having the highest average price in the 21st century?

# %%
#Homewrok
