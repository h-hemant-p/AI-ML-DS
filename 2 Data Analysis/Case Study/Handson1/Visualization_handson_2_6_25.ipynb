# %%
# https://drive.google.com/file/d/1UwUbeOSD3MlILBn4oa5VygCpSG09VneP/view?usp=sharing

# %%
# https://drive.google.com/file/d/1Ju9lHhSt750r-B237RqUE0lwFxg4NhUi/view?usp=sharing

# %%
import pandas as pd

# %%
df=pd.read_csv(r'/content/cars-1 (2).csv')

# %%
df
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  261 non-null    object
#  3   hp           261 non-null    int64
#  4   weightlbs    261 non-null    object
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %%
df['cubicinches'].unique()
# Out:
# array(['350', '89', '302', '400', '98', '351', '440', '183', '108', '97',
#        '225', '85', '304', '113', '107', '86', '121', '200', '91', '71',
#        '250', '120', '199', '231', '80', '232', ' ', '455', '318', '122',
#        '141', '340', '116', '156', '90', '360', '168', '305', '198',
#        '112', '119', '262', '134', '429', '115', '72', '105', '151', '88',
#        '307', '101', '79', '140', '114', '173', '144', '81', '267', '70',
#        '163', '171', '260', '131', '68', '96', '135', '390', '146', '258',
#        '83', '76', '383', '130', '110', '454'], dtype=object)

# %%
#object to numeric:to_numeric
#errors='coerce'-> converts all the error to null value
df['cubicinches']=pd.to_numeric(df['cubicinches'],errors='coerce')

# %%
df.isnull().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    2
# hp             0
# weightlbs      0
# time-to-60     0
# year           0
# brand          0
# dtype: int64

# %%
df['weightlbs'].unique()
# Out:
# array(['4209', '1925', '3449', '3761', '2051', '3900', '4363', '4312',
#        '3530', '2050', '2245', '2188', '4141', '3664', ' ', '4360',
#        '2020', '3433', '2278', '2430', '2019', '2600', '3012', '4054',
#        '1968', '1795', '1773', '4657', '3574', '2380', '2130', '3278',
#        '2506', '1985', '3415', '1835', '2720', '3955', '3265', '3897',
#        '4638', '3645', '3520', '3086', '2635', '3755', '2395', '1940',
#        '3060', '4464', '3190', '3609', '2158', '4380', '4278', '2930',
#        '2075', '1937', '3821', '2945', '2379', '2910', '2110', '4237',
#        '3525', '1950', '1965', '1825', '3880', '3102', '2640', '2288',
#        '2545', '2219', '3015', '3085', '2515', '2265', '2350', '4325',
#        '4952', '3425', '2694', '2220', '1613', '2774', '3465', '2125',
#        '1975', '2300', '4100', '3329', '2255', '3907', '4499', '3139',
#        '3830', '3781', '4997', '4906', '2126', '2200', '2335', '2065',
# ...

# %%
df['weightlbs']=pd.to_numeric(df['weightlbs'],errors='coerce')

# %%
df.isnull().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    2
# hp             0
# weightlbs      3
# time-to-60     0
# year           0
# brand          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 256 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          256 non-null    float64
#  1   cylinders    256 non-null    int64
#  2   cubicinches  256 non-null    float64
#  3   hp           256 non-null    int64
#  4   weightlbs    256 non-null    float64
#  5   time-to-60   256 non-null    int64
#  6   year         256 non-null    int64
#  7   brand        256 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 18.0+ KB

# %%
#subplots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.subplots(nrows=2,ncols=2)
plt.show()

# %%
# 1. Create scatter plots for the following data, make sure all the plots appear in the same
# plane with x-labels and y-labels evenly spaced.
# a. Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg,
# hp-time-to-60) with respect to each brand.

# %%
fig,axis=plt.subplots(2,2,figsize=(16,8))
sns.scatterplot(data=df,x='mpg',y='hp',ax=axis[0,0],hue='brand')
sns.scatterplot(data=df,x='mpg',y='weightlbs',ax=axis[0,1],hue='brand')
sns.scatterplot(data=df,x='hp',y='mpg',ax=axis[1,0],hue='brand')
sns.scatterplot(data=df,x='hp',y='time-to-60',ax=axis[1,1],hue='brand')
plt.show()

# %%
# 2. Create bar plots for the following, make sure all the plots appear in the same plane with
# x-labels and y-labels evenly spaced.
# a. Create a bar plot that shows the visual representation of hp, mpg, weight,
# time-to-60 with respect to the number of cylinders for each of the brands.
# b. Create a bar plot that shows the visual representation of hp, mpg, weight and
# time-to-60 with respect to the years, for each brand.

# %%
#a
fig,axis=plt.subplots(2,2,figsize=(16,8))
sns.barplot(data=df,x='cylinders',y='hp',hue='brand',ax=axis[0,0])
sns.barplot(data=df,x='cylinders',y='mpg',hue='brand',ax=axis[0,1])
sns.barplot(data=df,x='cylinders',y='weightlbs',hue='brand',ax=axis[1,0])
sns.barplot(data=df,x='cylinders',y='time-to-60',hue='brand',ax=axis[1,1])
plt.show()

# %%
#b
fig,axis=plt.subplots(2,2,figsize=(16,8))
sns.barplot(data=df,x='year',y='hp',hue='brand',ax=axis[0,0])
sns.barplot(data=df,x='year',y='mpg',hue='brand',ax=axis[0,1])
sns.barplot(data=df,x='year',y='weightlbs',hue='brand',ax=axis[1,0])
sns.barplot(data=df,x='year',y='time-to-60',hue='brand',ax=axis[1,1])
plt.show()

# %%
# 3. Create box plots for the following:

# a. Create box plots for the columns hp, mpg, weight, time-to-60 with respect brand

# %%
fig,axis=plt.subplots(2,2,figsize=(16,8))
sns.boxplot(data=df,y='hp',hue='brand',ax=axis[0,0])
sns.boxplot(data=df,y='mpg',hue='brand',ax=axis[0,1])
sns.boxplot(data=df,y='weightlbs',hue='brand',ax=axis[1,0])
sns.boxplot(data=df,y='time-to-60',hue='brand',ax=axis[1,1])
# Out:
# <Axes: ylabel='time-to-60'>

# %%
# 4. Create pair plots for the entire data to study various patterns in the data.
# a. Create pair plots with respect to brand

# %%
sns.pairplot(data=df,hue='brand')
plt.show()

# %%
# 5. Create a heatmap for the entire data to study correlation between each of the columns.

# %%
df.corr(numeric_only=True)
# Out:
#                   mpg  cylinders  cubicinches        hp  weightlbs  \
# mpg          1.000000  -0.776599    -0.803830 -0.779954  -0.824945
# cylinders   -0.776599   1.000000     0.951529  0.847450   0.897247
# cubicinches -0.803830   0.951529     1.000000  0.907341   0.930027
# hp          -0.779954   0.847450     0.907341  1.000000   0.863467
# weightlbs   -0.824945   0.897247     0.930027  0.863467   1.000000
# time-to-60   0.520401  -0.583449    -0.613344 -0.745310  -0.488671
# year         0.561719  -0.329193    -0.359215 -0.393079  -0.281156
#
#              time-to-60      year
# mpg            0.520401  0.561719
# cylinders     -0.583449 -0.329193
# cubicinches   -0.613344 -0.359215
# hp            -0.745310 -0.393079
# weightlbs     -0.488671 -0.281156
# time-to-60     1.000000  0.315549
# year           0.315549  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
# 6. Create a histogram for the following:
# a. Create histograms for hp, mpg, time-to-60, weight lbs, cubic inches, year, with
# respect to brand.

# %%
fig,axis=plt.subplots(3,2,figsize=(16,10))
sns.histplot(data=df,x='hp',hue='brand',ax=axis[0,0])
sns.histplot(data=df,x='mpg',hue='brand',ax=axis[0,1])
sns.histplot(data=df,x='time-to-60',hue='brand',ax=axis[1,0])
sns.histplot(data=df,x='weightlbs',hue='brand',ax=axis[1,1])
sns.histplot(data=df,x='cubicinches',hue='brand',ax=axis[2,0])
sns.histplot(data=df,x='year',hue='brand',ax=axis[2,1])
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
# 7. Create line plots for the following:
# a. Line plot between hp-mpg, hp-(time-to-60), mpg-(time-to-60), hp-weight lbs,
# mpg-weight lbs, cubic inches-weight lbs.

# %%
fig,axis=plt.subplots(3,2,figsize=(16,10))
sns.lineplot(data=df,x='hp',y='mpg',ax=axis[0,0])
sns.lineplot(data=df,x='hp',y='time-to-60',ax=axis[0,1])
sns.lineplot(data=df,x='mpg',y='time-to-60',ax=axis[1,0])
sns.lineplot(data=df,x='hp',y='weightlbs',ax=axis[1,1])
sns.lineplot(data=df,x='mpg',y='weightlbs',ax=axis[2,0])
sns.lineplot(data=df,x='cubicinches',y='weightlbs',ax=axis[2,1])
plt.show()

# %%
# 8. Create a pie chart for the following columns and their distribution in the data:
# a. Brands

# %%
df['brand'].value_counts()
# Out:
# brand
# US.        158
# Japan.      51
# Europe.     47
# Name: count, dtype: int64

# %%
df['brand'].value_counts().keys()
# Out:
# Index([' US.', ' Japan.', ' Europe.'], dtype='object', name='brand')

# %%
plt.pie(df['brand'].value_counts(),labels=df['brand'].value_counts().keys(),autopct='%.2f%%')
plt.show()

# %%
# 9. Create violin plots for the following:
# a. hp, mpg, time-to-60, with respect to the brand.

# %%
#box+kde plot

# %%
fig,axis=plt.subplots(2,2,figsize=(16,8))
sns.violinplot(data=df,x='hp',hue='brand',ax=axis[0,0])
sns.violinplot(data=df,x='mpg',hue='brand',ax=axis[0,1])
sns.violinplot(data=df,x='time-to-60',hue='brand',ax=axis[1,0])
sns.violinplot(data=df,x='weightlbs',hue='brand',ax=axis[1,1])
# Out:
# <Axes: xlabel='weightlbs'>

# %%
sns.kdeplot(data=df,x='hp',hue='brand')
# Out:
# <Axes: xlabel='hp', ylabel='Density'>
