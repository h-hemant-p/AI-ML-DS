# %%
# dataset:-https://drive.google.com/file/d/1-8m6SurRpr5j_nK2_-86xFUbtVuijmCT/view?usp=sharing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/purchase_data.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 263010  1004473  P00041942      M  36-45         1.0             B
# 263011  1004473  P00115142      M  36-45         1.0             B
# 263012  1004473  P00188442      M  36-45         1.0             B
# 263013  1004473  P00119442      M  36-45         1.0             B
# 263014       10        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# ...

# %%
df.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17        10.0             A
# 1  1000001  P00248942      F   0-17        10.0             A
# 2  1000001  P00087842      F   0-17        10.0             A
# 3  1000001  P00085442      F   0-17        10.0             A
# 4  1000002  P00285442      M    55+        16.0             C
# 5  1000003  P00193542      M  26-35        15.0             A
# 6  1000004  P00184942      M  46-50         7.0             B
# 7  1000004  P00346142      M  46-50         7.0             B
# 8  1000004   P0097242      M  46-50         7.0             B
# 9  1000005  P00274942      M  26-35        20.0             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# ...

# %%
df.tail(10)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 263005  1004472  P00149342      F  46-50        16.0             B
# 263006  1004472  P00034142      F  46-50        16.0             B
# 263007  1004472  P00251242      F  46-50        16.0             B
# 263008  1004473  P00045842      M  36-45         1.0             B
# 263009  1004473  P00296542      M  36-45         1.0             B
# 263010  1004473  P00041942      M  36-45         1.0             B
# 263011  1004473  P00115142      M  36-45         1.0             B
# 263012  1004473  P00188442      M  36-45         1.0             B
# 263013  1004473  P00119442      M  36-45         1.0             B
# 263014       10        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 263005                          0             1.0                13.0
# 263006                          0             1.0                 8.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263014 non-null  object
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
# EDA :- Explorartory Data analysis
# 1.cleaning the data
# 2.Null values
# 3.duplicates
# 4.outliers
# 5.label encoding
# 6.stats analysis

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
# 4+  --> 4
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].replace('4+','4')

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4', '3', '1', '0', nan], dtype=object)

# %%
df[['Stay_In_Current_City_Years']]=df[['Stay_In_Current_City_Years']].fillna('0')

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263015 non-null  int64
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(6), int64(2), object(4)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         1
# Gender                             1
# Age                                1
# Occupation                         1
# City_Category                      1
# Stay_In_Current_City_Years         0
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             81514
# Product_Category_3            182433
# Purchase                           1
# dtype: int64

# %%
p2_mean=df['Product_Category_2'].mean()
df['Product_Category_2']=df['Product_Category_2'].fillna(p2_mean)

# %%
p3_mean=df['Product_Category_2'].mean()
df['Product_Category_3']=df['Product_Category_3'].fillna(p3_mean)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    1
# Gender                        1
# Age                           1
# Occupation                    1
# City_Category                 1
# Stay_In_Current_City_Years    0
# Marital_Status                1
# Product_Category_1            1
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
for col in df.columns:
  if(df[col].dtype!='object'):
    sns.boxplot(df[col])
    plt.xlabel(col)
    plt.show()

# %%
df.shape
# Out:
# (263014, 12)

# %%
#steps : to calculate outliers
# Q1= df['Purchase'].quantile(0.25)
# Q3= df['Purchase'].quantile(0.75)

# IQR=Q3-Q1

# LB= Q1-1.5*(IQR)
# UB= Q3+1.5*(IQR)
# (LB,UB)
# df=df[(df['Purchase']>=LB) & (df['Purchase']<=UB)]

# %%
# df[(df['Purchase']<LB) | (df['Purchase']>UB)]

# %%
# len(df[(df['Purchase']<LB) | (df['Purchase']>UB)])

# %%
df.shape
# Out:
# (263014, 12)

# %%
263014-261725
# Out:
# 1289

# %%
out_list=['col1','col2','col2']

# %%
# #create a fucntion which will take out_lier column list and df as parameters and then it will return the outlier freee dataset
# for col in out_list:
#   Q1=df[col].quantile(0.25)
#   Q3=df[col].quantile(0.75)

#   IQR=Q3-Q1

#   LB=Q1-1.5*(IQR)
#   UB=Q3+1.5*(IQR)

#   df=df[(df[col]>=LB) & (df[col]<=UB)]

# %%
out_list=['Purchase']

# %%
def outlier_eliminator(df,out_list):
  for col in out_list:
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)

    IQR=Q3-Q1

    LB=Q1-1.5*(IQR)
    UB=Q3+1.5*(IQR)

    df=df[(df[col]>=LB) & (df[col]<=UB)]
  return df

# %%
df=outlier_eliminator(df,out_list)
df.shape  #(261725, 12)
# Out:
# (261725, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261725 entries, 0 to 263013
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     261725 non-null  int64
#  1   Product_ID                  261725 non-null  object
#  2   Gender                      261725 non-null  object
#  3   Age                         261725 non-null  object
#  4   Occupation                  261725 non-null  float64
#  5   City_Category               261725 non-null  object
#  6   Stay_In_Current_City_Years  261725 non-null  int64
#  7   Marital_Status              261725 non-null  float64
#  8   Product_Category_1          261725 non-null  float64
#  9   Product_Category_2          261725 non-null  float64
#  10  Product_Category_3          261725 non-null  float64
#  11  Purchase                    261725 non-null  float64
# dtypes: float64(6), int64(2), object(4)
# ...

# %%
# 'Male'  --> 1
# 'Female' -->0
# 0-->n-1  --> n = no .of unique values in the column
# '46' -->46

# %%
df['Age'].unique()  #'0-17'-->0  ,18-25 -->1
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
model=LabelEncoder()

# %%
for col in df.columns:
  if(df[col].dtype=='object'):
    df[col]=model.fit_transform(df[col])
# Out:
# /tmp/ipython-input-84-826484747.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=model.fit_transform(df[col])
# /tmp/ipython-input-84-826484747.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=model.fit_transform(df[col])
# /tmp/ipython-input-84-826484747.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261725 entries, 0 to 263013
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     261725 non-null  int64
#  1   Product_ID                  261725 non-null  int64
#  2   Gender                      261725 non-null  int64
#  3   Age                         261725 non-null  int64
#  4   Occupation                  261725 non-null  float64
#  5   City_Category               261725 non-null  int64
#  6   Stay_In_Current_City_Years  261725 non-null  int64
#  7   Marital_Status              261725 non-null  float64
#  8   Product_Category_1          261725 non-null  float64
#  9   Product_Category_2          261725 non-null  float64
#  10  Product_Category_3          261725 non-null  float64
#  11  Purchase                    261725 non-null  float64
# dtypes: float64(6), int64(6)
# memory usage: 26.0 MB

# %%
#getting infrences from dataset

#1.create a sample
#2.create hypothesis (HO(Null hypotheses) ad H1(Alternate hypo))
#3.Apply the appropriate test
#4.compare the p_value
  # a.if p_val>0.05  --> fail reject the null hypo (accecpt H0)
  # b.if p_val<=0.05  --> reject the null hypo (accecpt H1)

# %% [markdown]
# # a) It was observed that the average purchase made by the Men of the age 18-25 was 10000. Is it still the same?

# %% [markdown]
# **A one-sample t-test** is a statistical test used to determine whether the mean of a single sample is significantly different from a known or hypothesized population mean.
#
# It helps in testing hypotheses about the average value of a dataset.
#
# **Types of t-tests:**
#
# **One-sample t-test**: Compares the sample mean to a known value (population mean).
#
# **Independent two-sample t-test**: Compares the means of two independent groups.
#
# **Paired sample t-test**: Compares means from the same group at different times (e.g., before and after treatment).
#
# Key Concepts:
#
# Null Hypothesis (H₀): The sample mean is equal to the population mean.
#
# Alternative Hypothesis (H₁): The sample mean is different (greater or less) than the population mean.

# %%
new_data=df[(df['Gender']==1) & (df['Age']==1)]

# %%
new_data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 97      1000021        2024       1    1        16.0              1
# 98      1000022        3261       1    1        15.0              0
# 99      1000022        1954       1    1        15.0              0
# 100     1000022        1792       1    1        15.0              0
# 101     1000022        1020       1    1        15.0              0
# ...         ...         ...     ...  ...         ...            ...
# 262767  1004446        1311       1    1        18.0              1
# 262951  1004465        2880       1    1         4.0              0
# 262952  1004465        1296       1    1         4.0              0
# 262953  1004465        2733       1    1         4.0              0
# 262954  1004465        1424       1    1         4.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 97                               0             0.0                 3.0
# ...

# %%
sample=new_data.sample(3600)
sample
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 188795  1005133        3143       1    1        11.0              1
# 47689   1001311        2156       1    1        10.0              2
# 73472   1005319        2816       1    1        17.0              1
# 169868  1002172        3458       1    1        20.0              1
# 116024  1005915        1314       1    1         4.0              2
# ...         ...         ...     ...  ...         ...            ...
# 180585  1003884        1746       1    1         4.0              0
# 34800   1005367        2013       1    1         4.0              0
# 229314  1005365        1257       1    1        12.0              2
# 128227  1001733         418       1    1        14.0              1
# 58638   1003051        1362       1    1        17.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 188795                           0             0.0                 1.0
# ...

# %%
from scipy.stats import ttest_1samp

# %%
pop_mean=10000
t_val,p_val=ttest_1samp(sample['Purchase'],pop_mean)
p_val
# Out:
# np.float64(2.1911983696341416e-10)

# %%
p_val=2.1911983696341416-10

# %%
p_val
# Out:
# -8.808801630365858

# %%
# avg of current men of age 18-25 is not 10000
new_data['Purchase'].mean()
# Out:
# np.float64(9391.676371471189)

# %% [markdown]
# # b) It was observed that the percentage of women that spend more than 10000 was 35%. Is it still the same?

# %%
new_df=df[df['Purchase']>10000]

# %%
new_df
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 1       1000001        2304       0    0        10.0              0
# 5       1000003        1768       1    2        15.0              0
# 6       1000004        1684       1    4         7.0              1
# 7       1000004        3213       1    4         7.0              1
# 8       1000004        3481       1    4         7.0              1
# ...         ...         ...     ...  ...         ...            ...
# 262997  1004472        2433       0    4        16.0              1
# 263001  1004472        1921       0    4        16.0              1
# 263002  1004472        1665       0    4        16.0              1
# 263003  1004472        3209       0    4        16.0              1
# 263011  1004473        1015       1    3         1.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                                2             0.0                 1.0
# ...

# %%
new_df['Gender'].value_counts()
# Out:
# Gender
# 1    71366
# 0    18402
# Name: count, dtype: int64

# %%
male=71366
female=18402
pra=0.35
total=male+female

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
z_val,p_val=proportions_ztest(count=female,nobs=total,value=pra)

# %%
p_val
# Out:
# np.float64(0.0)

# %%
((female/total)*100)
# Out:
# 20.499509847607165

# %% [markdown]
# # c) Is the percentage of men who have spent more than 10000 the same for the ages 18-25 and 26-35?

# %%
data1=df[ (df['Age']==1) & (df['Purchase']>10000)]
data2=df[(df['Age']==2) & (df['Purchase']>10000)]

# %%
data1
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 71      1000018        1740       0    1         3.0              1
# 73      1000018         990       0    1         3.0              1
# 74      1000018        1048       0    1         3.0              1
# 75      1000018         332       0    1         3.0              1
# 76      1000018        2044       0    1         3.0              1
# ...         ...         ...     ...  ...         ...            ...
# 262758  1004446        1138       1    1        18.0              1
# 262759  1004446        2312       1    1        18.0              1
# 262762  1004446        1152       1    1        18.0              1
# 262763  1004446         998       1    1        18.0              1
# 262767  1004446        1311       1    1        18.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 71                               3             0.0                 3.0
# ...

# %%
data1['Gender'].value_counts()
# Out:
# Gender
# 1    13195
# 0     3264
# Name: count, dtype: int64

# %%
data2['Gender'].value_counts()
# Out:
# Gender
# 1    29177
# 0     6716
# Name: count, dtype: int64

# %%
counts=[13195,29177]
total=[16459,35893]

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
z_val,p_val=proportions_ztest(count=counts,nobs=total,value=0)

# %%
p_val
# Out:
# np.float64(0.0024559930338846326)

# %%
counts[0]/total[0]
# Out:
# 0.8016890455070175

# %%
counts[1]/total[1]
# Out:
# 0.8128883069122113

# %%
# Is the average purchase made by men and women of the age 18-25 same
